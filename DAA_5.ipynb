# %%
# 0/1 Knapsack Problem using Dynamic Programming

import time


def knapsack(weights, values, capacity):
    n = len(weights)

    # Create DP table
    dp = [[0 for _ in range(capacity + 1)]
          for _ in range(n + 1)]

    # Fill the DP table
    for i in range(1, n + 1):
        for w in range(1, capacity + 1):

            if weights[i - 1] <= w:
                dp[i][w] = max(
                    values[i - 1] + dp[i - 1][w - weights[i - 1]],
                    dp[i - 1][w]
                )
            else:
                dp[i][w] = dp[i - 1][w]

    return dp[n][capacity]


# -------------------------------
# User Input
# -------------------------------

n = int(input("Enter number of items: "))

weights = []
values = []

for i in range(n):
    weight = int(input(f"Enter weight of item {i + 1}: "))
    value = int(input(f"Enter value of item {i + 1}: "))

    weights.append(weight)
    values.append(value)

capacity = int(input("Enter knapsack capacity: "))


# -------------------------------
# Calculate Execution Time
# -------------------------------

start_time = time.perf_counter()

result = knapsack(weights, values, capacity)

end_time = time.perf_counter()

execution_time = end_time - start_time


# -------------------------------
# Output
# -------------------------------

print("\n========== 0/1 KNAPSACK PROBLEM ==========")

print("Weights:", weights)
print("Values :", values)
print("Capacity:", capacity)

print("\nMaximum Profit/Value:", result)

print("\nExecution Time:", execution_time, "seconds")

print("\nTime Complexity: O(n × W)")
# Out:
# Enter number of items:  5
# Enter weight of item 1:  3
# Enter value of item 1:  12
# Enter weight of item 2:  9
# Enter value of item 2:  50
# Enter weight of item 3:  4
# Enter value of item 3:  54
# Enter weight of item 4:  5
# Enter value of item 4:  7
# Enter weight of item 5:  3
# Enter value of item 5:  150
# Enter knapsack capacity:  9
# ========== 0/1 KNAPSACK PROBLEM ==========
# Weights: [3, 9, 4, 5, 3]
# Values : [12, 50, 54, 7, 150]
# Capacity: 9
#
# Maximum Profit/Value: 204
#
# Execution Time: 0.000291000003926456 seconds
#
# Time Complexity: O(n × W)
