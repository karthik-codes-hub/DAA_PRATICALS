# %% [markdown]
# # Implementation and Time analysis of factorial program using iterative and recursive method

# %%
import time
import sys

# Increase recursion limit for larger values
sys.setrecursionlimit(10000)

# -------------------------------
# Iterative Factorial
# -------------------------------
def factorial_iterative(n):
    result = 1

    for i in range(1, n + 1):
        result *= i

    return result


# -------------------------------
# Recursive Factorial
# -------------------------------
def factorial_recursive(n):
    if n == 0 or n == 1:
        return 1

    return n * factorial_recursive(n - 1)


# -------------------------------
# Main Program
# -------------------------------

n = int(input("Enter a positive integer: "))

if n < 0:
    print("Factorial is not defined for negative numbers.")
else:

    # Iterative method
    start_time = time.perf_counter()
    iterative_result = factorial_iterative(n)
    end_time = time.perf_counter()

    iterative_time = end_time - start_time

    # Recursive method
    start_time = time.perf_counter()
    recursive_result = factorial_recursive(n)
    end_time = time.perf_counter()

    recursive_time = end_time - start_time

    # Display Results
    print("\n========== FACTORIAL RESULT ==========")
    print("Number:", n)
    print("Factorial:", iterative_result)

    print("\n---------- Iterative Method ----------")
    print("Execution Time:", iterative_time, "seconds")
    print("Time Complexity:")
    print("Best Case   : O(n)")
    print("Average Case: O(n)")
    print("Worst Case  : O(n)")

    print("\n---------- Recursive Method ----------")
    print("Execution Time:", recursive_time, "seconds")
    print("Time Complexity:")
    print("Best Case   : O(n)")
    print("Average Case: O(n)")
    print("Worst Case  : O(n)")
# Out:
# Enter a positive integer:  5
# ========== FACTORIAL RESULT ==========
# Number: 5
# Factorial: 120
#
# ---------- Iterative Method ----------
# Execution Time: 9.100011084228754e-06 seconds
# Time Complexity:
# Best Case   : O(n)
# Average Case: O(n)
# Worst Case  : O(n)
#
# ---------- Recursive Method ----------
# Execution Time: 5.699985194951296e-06 seconds
# Time Complexity:
# Best Case   : O(n)
# Average Case: O(n)
# Worst Case  : O(n)
